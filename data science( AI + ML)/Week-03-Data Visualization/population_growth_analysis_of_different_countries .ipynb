# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
country_data=pd.read_csv("countries.csv")

# %%
country_data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
pk=country_data[country_data.country=='Pakistan']

# %%
pk
# Out:
#        country  year  population
# 1164  Pakistan  1952    41346560
# 1165  Pakistan  1957    46679944
# 1166  Pakistan  1962    53100671
# 1167  Pakistan  1967    60641899
# 1168  Pakistan  1972    69325921
# 1169  Pakistan  1977    78152686
# 1170  Pakistan  1982    91462088
# 1171  Pakistan  1987   105186881
# 1172  Pakistan  1992   120065004
# 1173  Pakistan  1997   135564834
# 1174  Pakistan  2002   153403524
# 1175  Pakistan  2007   169270617

# %%
ind=country_data[country_data.country=='India']

# %%
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
afg=country_data[country_data.country=='Afghanistan']

# %%
afg
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
#display population growth by year of  countries
plt.plot(afg.year,afg.population/1000000)#dividing population by 1 million
plt.plot(ind.year, ind.population / 10**6)
plt.plot(pk.year,pk.population/10**6)
plt.legend(['Afghanistan', 'India','Pakistan'])#jo graph phly ha phla label usko mily ga
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
#display population growth by year of  countries by percentage
plt.plot(afg.year,afg.population/afg.population.iloc[0]*100)#dividing population by 1 million
plt.plot(ind.year, ind.population /ind.population.iloc[0]*100)
plt.plot(pk.year,pk.population/pk.population.iloc[0]*100)
plt.legend(['Afghanistan', 'India','Pakistan'])#jo graph phly ha phla label usko mily ga
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
zim=country_data[country_data.country=='Zimbabwe']

# %%
zim
# Out:
#        country  year  population
# 1692  Zimbabwe  1952     3080907
# 1693  Zimbabwe  1957     3646340
# 1694  Zimbabwe  1962     4277736
# 1695  Zimbabwe  1967     4995432
# 1696  Zimbabwe  1972     5861135
# 1697  Zimbabwe  1977     6642107
# 1698  Zimbabwe  1982     7636524
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
zom=country_data[country_data.country=='Zambia']

# %%
zom
# Out:
#      country  year  population
# 1680  Zambia  1952     2672000
# 1681  Zambia  1957     3016000
# 1682  Zambia  1962     3421000
# 1683  Zambia  1967     3900000
# 1684  Zambia  1972     4506497
# 1685  Zambia  1977     5216550
# 1686  Zambia  1982     6100407
# 1687  Zambia  1987     7272406
# 1688  Zambia  1992     8381163
# 1689  Zambia  1997     9417789
# 1690  Zambia  2002    10595811
# 1691  Zambia  2007    11746035

# %%
wbg=country_data[country_data.country=='West Bank and Gaza']

# %%
wbg
# Out:
#                  country  year  population
# 1656  West Bank and Gaza  1952     1030585
# 1657  West Bank and Gaza  1957     1070439
# 1658  West Bank and Gaza  1962     1133134
# 1659  West Bank and Gaza  1967     1142636
# 1660  West Bank and Gaza  1972     1089572
# 1661  West Bank and Gaza  1977     1261091
# 1662  West Bank and Gaza  1982     1425876
# 1663  West Bank and Gaza  1987     1691210
# 1664  West Bank and Gaza  1992     2104779
# 1665  West Bank and Gaza  1997     2826046
# 1666  West Bank and Gaza  2002     3389578
# 1667  West Bank and Gaza  2007     4018332

# %%
#display population growth by year of  countries
plt.plot(zim.year,zim.population/1000000)#dividing population by 1 million
plt.plot(zom.year, zom.population / 10**6)
plt.plot(wbg.year,wbg.population/10**6)
plt.legend(['Zimbabwe', 'Zambia','West Bank and Gaza'])#jo graph phly ha phla label usko mily ga
plt.xlabel('year')
plt.ylabel('population')
plt.show()

# %%
plt.plot(zim.year,zim.population/zim.population.iloc[0]*100)#dividing population by 1 million
plt.plot(zom.year, zom.population / zom.population.iloc[0]*100)
plt.plot(wbg.year,wbg.population/wbg.population.iloc[0]*100)
plt.legend(['Zimbabwe', 'Zambia','West Bank and Gaza'])#jo graph phly ha phla label usko mily ga
plt.xlabel('year')
plt.ylabel('population')
plt.show()
